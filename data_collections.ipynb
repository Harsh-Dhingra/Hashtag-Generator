# %%
# !pip install instaloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for instaloader: filename=instaloader-4.10-py3-none-any.whl size=64278 sha256=b46daf787e5561de80147cf459db786ece9e21a4e8acb17dd334dc09db1fac14
#   Stored in directory: /root/.cache/pip/wheels/5b/8d/e0/866c1ad8efef4ab789acf51c4b317711d63f62af0228a6a676
# Successfully built instaloader
# ...

# %%
#wedding : weddingsutra,

#Motivational Quotes/talk : thegoodquote

#sports: starsportsindia,espncricinfo

#art nancy_sketch_artist_

#code : coding_memes,coding_comedy

# food: foodfusion,thefoodierider_hyderabad,justeatssss
# !instaloader '#code'  coding_comedy --no-videos --no-captions --no-metadata-json --no-compress-json --count 10
# Out:
# JSON Query to explore/tags/code/: HTTP error code 401. [retrying; skip with ^C]
# JSON Query to explore/tags/code/: HTTP error code 401. [retrying; skip with ^C]
# Get hashtag #code: JSON Query to explore/tags/code/: HTTP error code 401.
# Stored ID 26038919389 for profile coding_comedy.
# Hint: Use --login to download higher-quality versions of pictures.
# [1/1] Downloading profile coding_comedy
# coding_comedy/2020-01-14_00-30-55_UTC_profile_pic.jpg
# Retrieving posts from profile coding_comedy.
# [   1/2991] coding_comedy/2023-08-13_22-07-58_UTC.jpg
# [   2/2991] coding_comedy/2023-08-12_14-40-47_UTC.jpg
# [   3/2991] coding_comedy/2023-08-11_01-54-05_UTC.jpg
# [   4/2991] coding_comedy/2023-08-09_14-54-38_UTC.jpg
# [   5/2991] coding_comedy/2023-08-08_23-14-19_UTC.jpg
# [   6/2991] coding_comedy/2023-08-08_03-49-18_UTC.jpg
# [   7/2991] coding_comedy/2023-08-06_17-59-43_UTC.jpg
# [   8/2991] coding_comedy/2023-08-05_14-53-54_UTC.jpg
# ...

# %%
# !instaloader --help
# Out:
# usage:
# instaloader [--comments] [--geotags]
#             [--stories] [--highlights] [--tagged] [--igtv]
#             [--login YOUR-USERNAME] [--fast-update]
#             profile | "#hashtag" | %location_id | :stories | :feed | :saved
# instaloader --help
#
# Download
# pictures
# (or videos)
# along with
# their
# captions
# and other
# metadata
# from
# Instagram.
#
# What to Download:
#   Specify a
#   list of
#   targets.
#   For each
#   of these,
#   Instaload
#   er
#   creates a
#   folder
#   and
#   downloads
#   all
#   posts.
#   The
#   following
#   targets
#   are suppo
#   rted:
#
#   profile
#     Download
#     profile. If
#     an already-
#     downloaded
#     profile has
#     been
#     renamed,
#     Instaloader
#     automatical
#     ly finds it
#     by its
#     unique ID
#     and renames
#     the folder
#     likewise.
#   @profile
#     Download
#     all
#     followees
#     of profile.
#     Requires
#     --login.
#     Consider
# ...

# %%
import subprocess

def run_command(command):
    try:
        subprocess.run(command, check=True)
        print("Command executed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error executing command: {e}")
    except Exception as ex:
        print(f"An error occurred: {ex}")

# Example usage:
command = ["instaloader", "#food", "coding_comedy", "--no-videos", "--no-captions", "--no-metadata-json", "--no-compress-json", "--count", "700"]
run_command(command)
# Out:
# Command executed successfully.

# %% [markdown]
# ### helper functions

# %%
import os

def remove_files_except_jpg(folder_path):
    # List all files in the folder
    files = os.listdir(folder_path)

    # Iterate through each file in the folder
    for file in files:
        # Check if the file does not have a JPG extension
        if not file.lower().endswith('.jpg'):
            # Get the full file path
            file_path = os.path.join(folder_path, file)

            # Check if the file is a directory
            if os.path.isdir(file_path):
                # Recursively remove files in the subdirectory
                remove_files_except_jpg(file_path)
            else:
                # Remove the file
                os.remove(file_path)



remove_files_except_jpg("coding_memes/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a0023438efe7> in <cell line: 24>()
#      22
#      23
# ---> 24 remove_files_except_jpg("coding_memes/")
#
# <ipython-input-4-a0023438efe7> in remove_files_except_jpg(folder_path)
#       3 def remove_files_except_jpg(folder_path):
#       4     # List all files in the folder
# ----> 5     files = os.listdir(folder_path)
#       6
#       7     # Iterate through each file in the folder
#
# FileNotFoundError: [Errno 2] No such file or directory: 'coding_memes/'

# %%
import os
import random
import shutil

def select_random_images(source_folder, destination_folder, num_images=800):
    # Get the list of all image files in the source folder
    image_files = [file for file in os.listdir(source_folder) if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

    # Check if the number of images to select is greater than the available images
    num_images = min(num_images, len(image_files))

    # Randomly select num_images from the list
    selected_images = random.sample(image_files, num_images)

    # Create the destination folder if it does not exist
    os.makedirs(destination_folder, exist_ok=True)

    # Copy the selected images to the destination folder
    for image in selected_images:
        source_path = os.path.join(source_folder, image)
        destination_path = os.path.join(destination_folder, image)
        shutil.copy(source_path, destination_path)

source_folder = "nancy_sketch_artist_/"
destination_folder = "art"
num_images_to_select = 800

select_random_images(source_folder, destination_folder, num_images_to_select)

# %%
import os
import random
import shutil

def randomly_select_and_move_files(source_folder, destination_folder, num_files=10):
    # Get the list of all files in the source folder
    all_files = os.listdir(source_folder)

    # Check if the number of files to select is greater than the available files
    num_files = min(num_files, len(all_files))

    # Randomly select num_files from the list
    selected_files = random.sample(all_files, num_files)

    # Create the destination folder if it does not exist
    os.makedirs(destination_folder, exist_ok=True)

    # Move the selected files to the destination folder
    for file in selected_files:
        source_path = os.path.join(source_folder, file)
        destination_path = os.path.join(destination_folder, file)
        shutil.move(source_path, destination_path)


source_folder = "final_data/art/"
destination_folder = "art_test"
num_files_to_select = 200

randomly_select_and_move_files(source_folder, destination_folder, num_files_to_select)
